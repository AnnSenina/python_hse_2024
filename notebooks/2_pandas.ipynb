# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnSenina/python_hse_2024/blob/main/notebooks/2_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #pandas
# pandas - библиотека, которая позволяет работать с табличными данными

# %%
#!pip install pandas

# %%
import pandas as pd # импортируем pandas в тетрадку

# %% [markdown]
# документация для pandas [здесь](https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html)
#
# Основные элементы "табличек в pandas" - это Series и Dataframe
#
# Series - это объект, похожий на одномерный массив с элементами и  индексами вдоль каждого элемента из списка.
#
# DataFrame "собирается" из таких Series

# %% [markdown]
# <img alt="Series vs DataFrame" height="300" width="700" src="https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png" >

# %% [markdown]
# # Создание датафрейма

# %% [markdown]
# Создать датафрейм можно несколькими способами:
# - из списка список - нативный путь
# - из словаря методом pd.DataFrame.from_dict()
# - прочитав .csv файл
#
# ### Первый способ

# %%
b = [[1, 2.1],
     [3, 4.444, 5]] # самый удобный вариант
b_df = pd.DataFrame(b) # краткий способ
b_df
# pd.DataFrame - обращение к библиотеке, создай таблицу (датафрейм)
# Out:
#    0      1    2
# 0  1  2.100  NaN
# 1  3  4.444  5.0

# %%
# в PyChram и др. программах - пишем print(b_df)
# в тетрадках - лучше без - в режиме display()

print(b_df)
b_df
# Out:
#    0      1    2
# 0  1  2.100  NaN
# 1  3  4.444  5.0
#    0      1    2
# 0  1  2.100  NaN
# 1  3  4.444  5.0

# %%
# можно создать датафрейм не только из списка списков, а например, напрямую из словаря

data = {
    "Maria": ["London", 37],
    "Lorenzo": ["Milan", 28],
    "Oleg": ["Canberra", 31],
    "Hans": ["Calgary", 80],
    "Mark": ["Milan", 55],
    "Alex": ["Krakow", 35],
    "Julia": ["Murmansk", 43]
}

# шаг 2 используем метод pd.DataFrame.from_dict()
# аргументом подадим созданный словарь

postcards = pd.DataFrame.from_dict(data).T
postcards
# Out:
#                 0   1
# Maria      London  37
# Lorenzo     Milan  28
# Oleg     Canberra  31
# Hans      Calgary  80
# Mark        Milan  55
# Alex       Krakow  35
# Julia    Murmansk  43

# %%
pd.DataFrame.from_dict(data)
# Out:
#     Maria Lorenzo      Oleg     Hans   Mark    Alex     Julia
# 0  London   Milan  Canberra  Calgary  Milan  Krakow  Murmansk
# 1      37      28        31       80     55      35        43

# %%
pd.DataFrame.from_dict(data).T # T - транспонировать (как в Excel!)
# Out:
#                 0   1
# Maria      London  37
# Lorenzo     Milan  28
# Oleg     Canberra  31
# Hans      Calgary  80
# Mark        Milan  55
# Alex       Krakow  35
# Julia    Murmansk  43

# %%
# еще один вариант с помощью from_dict
# вместо .T указываем orient="index" внутри from_dict

postcards = pd.DataFrame.from_dict(data, orient="index")

postcards
# Out:
#                 0   1
# Maria      London  37
# Lorenzo     Milan  28
# Oleg     Canberra  31
# Hans      Calgary  80
# Mark        Milan  55
# Alex       Krakow  35
# Julia    Murmansk  43

# %%
postcards.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
# давайте зададим приличные названия столбцов
postcards.columns = ['city', 'age']
postcards
# Out:
#              city  age
# Maria      London   37
# Lorenzo     Milan   28
# Oleg     Canberra   31
# Hans      Calgary   80
# Mark        Milan   55
# Alex       Krakow   35
# Julia    Murmansk   43

# %%
print(postcards.columns)
# Out:
# Index(['city', 'age'], dtype='object')

# %% [markdown]
# ### Из файла

# %%
# прочитаем .csv файл методом pd.read_csv()
# Важно! Чтобы этот способ сработал, нужно, чтобы питон нашел ваш файл

recipes = pd.read_csv("christmas_recipes.csv", sep=',') # есть другие аргументы: sep, decimal и др.
recipes

# %%
# Важно!
# С гитхаба csv читаются почти напрямую
# Для этого нужна raw-ссылка

recipes = pd.read_csv("https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/christmas_recipes.csv", sep=',')
recipes
# Out:
#                                                 Title  Time       Servings  \
# 0                                Perfect roast turkey   180  10 serving(s)
# 1                         Stuffed roast turkey breast   180   8 serving(s)
# 2     Nigella's turkey breast with Christmas stuffing   150  12 serving(s)
# 3                  Gordon Ramsay's roast turkey crown   120   8 serving(s)
# 4                                  Roast turkey crown   180   8 serving(s)
# 5                                   Roast turkey roll   150   8 serving(s)
# 6                           Roast turkey and stuffing   150  12 serving(s)
# 7                        Perfect roast chicken dinner   150   4 serving(s)
# 8   Venison Wellington with caramelised onions and...   120   6 serving(s)
# 9                                          Roast beef   120   6 serving(s)
# 10                  The ultimate Christmas roast beef   120   8 serving(s)
# 11                                    Beef Wellington   120   8 serving(s)
# 12  Roast pork belly with apple bread sauce and ri...   150   6 serving(s)
# 13            Honey and marmalade-glazed gammon joint   150  20 serving(s)
# 14                                Honey-glazed gammon   150  10 serving(s)
# 15              Slow cooked gammon with mustard sauce   150  12 serving(s)
# 16                               Christmas roast duck   180   6 serving(s)
# 17                                        Roast goose   150   6 serving(s)
# 18                                          Porchetta   120   6 serving(s)
# 19                                   Salmon en croûte    60  12 serving(s)
# 20            Christmas nut roast with mushroom gravy    30   8 serving(s)
# 21          Vegetarian nut roast pie with cranberries    60  10 serving(s)
# 22                                     Easy nut roast    30  10 serving(s)
# 23  Baked stuffed aubergine with walnut and Roquefort    60   8 serving(s)
# 24                     Brussels sprouts with pancetta    30   8 serving(s)
# 25                                Best roast potatoes    60   8 serving(s)
# 26                                  Christmas carrots    30   4 serving(s)
# 27                              Christmas red cabbage    60   4 serving(s)
# 28                    Mary Berry's Christmas stuffing    30     16 item(s)
# 29                                   Pigs in blankets    30   8 serving(s)
# 30                                Honey roast carrots    60   6 serving(s)
# 31                            Creamy Brussels sprouts    30   6 serving(s)
# 32                         Make-ahead Christmas gravy    30   8 serving(s)
# 33                                Braised red cabbage    30   8 serving(s)
# 34                             Perfect roast potatoes    60   8 serving(s)
# 35                                  Chestnut stuffing    30   6 serving(s)
# 36                               Maple-roast parsnips    60   8 serving(s)
# 37                     Hasselback potatoes with bacon    60     30 item(s)
# 38                            Sage and onion stuffing    60   6 serving(s)
# 39                          Sticky cranberry sausages    30  10 serving(s)
# 40                                   Easy bread sauce    30   8 serving(s)
# 41                        Slow cooker honey roast ham   150  10 serving(s)
#
#                                           Ingredients  \
# 0   ['20ml/¾fl oz rapeseed oil', '1 x 5kg/11lb goo...
# 1   ['1 tbsp sunflower oil', '1 onion, finely chop...
# 2   ['100g/3½oz dried cranberries', '100ml/3½fl oz...
# 3   ['125g/4½oz pack unsalted butter, softened', '...
# 4   ['1 turkey breast crown (a wingless, legless t...
# 5   ['100g/3½oz pork scratchings', '100g/3½oz sour...
# 6   ['4.5-5.5kg/10-12lb whole turkey, with giblets...
# 7   ['500ml/18fl oz milk', '75g/2½oz butter', '8 c...
# 8   ['1 tbsp olive oil', '750g/1lb 10oz venison fi...
# 9   ['225g/8oz plain flour', '8 free-range eggs', ...
# 10  ['225g/8oz plain flour', '8 free-range eggs', ...
# 11  ['1.3kg/2lb 14oz middle-cut fillet of beef', '...
# 12  ['1.8kg/4lb pork belly', '4 tbsp sea salt flak...
# 13  ['6kg/13lb 3½oz gammon joint', 'fresh orange j...
# 14  ['2kg/4lb 8oz unsmoked boneless gammon joint, ...
# 15  ['3kg/6lb 8oz unsmoked gammon joint, off the b...
# 16  ['1.5kg/3lb 5oz potatoes, peeled and thinly sl...
# 17  ['1 x 5kg/11lb oven-ready goose', '1 onion, pe...
# 18  ['3 tbsp finely chopped rosemary', 'sprig thym...
# 19  ['2 medium cucumbers, peeled', '5 tbsp Dijon m...
# 20  ['300g/10½oz spinach or chard leaves', '50g/1¾...
# 21  ['drizzle olive oil', '4 leeks, finely sliced'...
# 22  ['butter, for greasing and frying', '2 tbsp oi...
# 23  ['4 large aubergines', '2 garlic cloves, chopp...
# 24  ['salt', '900g/2lb 4oz Brussels sprouts, trimm...
# 25  ['10 large King Edward potatoes, peeled, cut i...
# 26  ['9 medium carrots, peeled, topped and tailed'...
# 27  ['1 tbsp walnut oil', '15g/½oz butter', '2 red...
# 28  ['40g/1½oz butter, plus extra for greasing', '...
# 29  ['8 thin slices streaky bacon', '16 chipolata ...
# 30  ['1 kg/2lb 4oz small carrots, such as Chantena...
# 31  ['500g/1lb 2oz Brussels sprouts, trimmed and h...
# 32  ['1 tbsp light olive oil or vegetable oil', '3...
# 33  ['1 red cabbage, quartered, cored and sliced',...
# 34  ['5 tbsp duck fat', '16 medium-sized Maris Pip...
# 35  ['1 large onion, coarsely chopped', '225g/8oz ...
# 36  ['1kg/2¼lb parsnips', '125ml/4fl oz vegetable ...
# 37  ['1kg/2lb 4oz small baby potatoes', '300g/10½o...
# 38  ['1 onion, peeled and finely chopped', '1 tbsp...
# 39  ['2 red onions, sliced', '2 tbsp olive oil', '...
# 40  ['1 large onion, peeled', '6 cloves', '1 bay l...
# 41  ['1.6kg/3lb 8oz boneless, rolled smoked or uns...
#
#                                          Instructions  \
# 0   Remove the turkey from the fridge and bring to...
# 1   To make the stuffing, heat the oil and gently ...
# 2   Put the cranberries and Marsala into a small s...
# 3   Pre-heat the oven to 200C/180C Fan/Gas 6.\nFor...
# 4   Preheat the oven to 220C/200C Fan/Gas 7.\nRub ...
# 5   For the crumble topping, crush the pork scratc...
# 6   For the stock, put the giblets, onion, carrot,...
# 7   For the bread sauce, heat together the first e...
# 8   Heat the oil in a large frying pan over a high...
# 9   For the Yorkshire puddings, put the flour in a...
# 10  First prepare the Yorkshire pudding batter. Po...
# 11  Preheat the oven to 220C/200C Fan/Gas 7.\nSeas...
# 12  Preheat the oven to 230C/210C fan/Gas 8.\nFor ...
# 13  For the gammon, place the gammon into a large,...
# 14  Place the gammon joint into a large lidded sau...
# 15  Preheat the oven to 160C/140C Fan/Gas 3.\nTo m...
# 16  Arrange the shelves of your oven so that there...
# 17  Preheat the oven to 200C/180C Fan/Gas 6.\nPlac...
# 18  For the paste filling, either put all the ingr...
# 19  Preheat the oven to 180C/350F/Gas 4. Line a la...
# 20  Preheat the oven to 200C/180C Fan/Gas 6. Line ...
# 21  Preheat the oven to 200C/400F/Gas 6 and grease...
# 22  Pre-heat the oven to 180C/160C Fan/Gas 4. Butt...
# 23  Preheat the oven to 200C/440F/Gas 6.\nCut the ...
# 24  Bring a saucepan of salted water to the boil a...
# 25  Preheat the oven to 200C/180C Fan/Gas 6.\nSimm...
# 26  Use a clean scourer to smooth the carrots and ...
# 27  Heat the oil and butter in a large heavy-based...
# 28  Melt the butter in a saucepan over a medium he...
# 29  Preheat the oven to 200C/180C Fan/Gas 6.\nPlac...
# 30  Preheat the oven to 200C/ 180C Fan/Gas 6. Trim...
# 31  Half-fill a medium saucepan with water and bri...
# 32  Preheat the oven to 200C/180C Fan/Gas 6.\nMix ...
# 33  Preheat the oven to 170C/150C Fan/Gas 3.\nMix ...
# 34  Preheat the oven to 190C/170C Fan/Gas 5.\nParb...
# 35  Preheat oven 200C/400F/Gas 6. Butter a shallow...
# 36  Preheat the oven to 200C/180C Fan/Gas 6.\nPeel...
# 37  Preheat the oven to 200C/180C Fan/Gas 6\nCut n...
# 38  Sweat the onion in the oil, until soft but not...
# 39  Fry the sliced red onions in a pan with the oi...
# 40  Press all the cloves into the whole peeled oni...
# 41  Put the gammon, onion and 100ml/3½fl oz water ...
#
#                                                 Image
# 0   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 1   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 2   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 3   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 4   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 5   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 6   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 7   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 8   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 9   https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 10  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 11  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 12  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 13  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 14  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 15  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 16  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 17  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 18  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 19  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 20  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 21  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 22  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 23  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 24  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 25  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 26  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 27  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 28  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 29  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 30  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 31  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 32  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 33  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 34  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 35  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 36  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 37  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 38  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 39  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 40  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 41  https://ichef.bbci.co.uk/food/ic/food_16x9_832...

# %% [markdown]
# ### Как посмотреть на часть датафрейма
#
# понадобятся методы ```.head()```, ```.tail()``` или индексация

# %%
recipes.head(3) # по умолчанию показывает первые 5 строк
# Out:
#                                              Title  Time       Servings  \
# 0                             Perfect roast turkey   180  10 serving(s)
# 1                      Stuffed roast turkey breast   180   8 serving(s)
# 2  Nigella's turkey breast with Christmas stuffing   150  12 serving(s)
#
#                                          Ingredients  \
# 0  ['20ml/¾fl oz rapeseed oil', '1 x 5kg/11lb goo...
# 1  ['1 tbsp sunflower oil', '1 onion, finely chop...
# 2  ['100g/3½oz dried cranberries', '100ml/3½fl oz...
#
#                                         Instructions  \
# 0  Remove the turkey from the fridge and bring to...
# 1  To make the stuffing, heat the oil and gently ...
# 2  Put the cranberries and Marsala into a small s...
#
#                                                Image
# 0  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 1  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 2  https://ichef.bbci.co.uk/food/ic/food_16x9_832...

# %%
recipes.tail(2) # последние строки (по умолчанию их тоже 5)
# Out:
#                           Title  Time       Servings  \
# 40             Easy bread sauce    30   8 serving(s)
# 41  Slow cooker honey roast ham   150  10 serving(s)
#
#                                           Ingredients  \
# 40  ['1 large onion, peeled', '6 cloves', '1 bay l...
# 41  ['1.6kg/3lb 8oz boneless, rolled smoked or uns...
#
#                                          Instructions  \
# 40  Press all the cloves into the whole peeled oni...
# 41  Put the gammon, onion and 100ml/3½fl oz water ...
#
#                                                 Image
# 40  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 41  https://ichef.bbci.co.uk/food/ic/food_16x9_832...

# %%
recipes[15:18] # часть датафрейма по индексам строчек
# Out:
#                                     Title  Time       Servings  \
# 15  Slow cooked gammon with mustard sauce   150  12 serving(s)
# 16                   Christmas roast duck   180   6 serving(s)
# 17                            Roast goose   150   6 serving(s)
#
#                                           Ingredients  \
# 15  ['3kg/6lb 8oz unsmoked gammon joint, off the b...
# 16  ['1.5kg/3lb 5oz potatoes, peeled and thinly sl...
# 17  ['1 x 5kg/11lb oven-ready goose', '1 onion, pe...
#
#                                          Instructions  \
# 15  Preheat the oven to 160C/140C Fan/Gas 3.\nTo m...
# 16  Arrange the shelves of your oven so that there...
# 17  Preheat the oven to 200C/180C Fan/Gas 6.\nPlac...
#
#                                                 Image
# 15  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 16  https://ichef.bbci.co.uk/food/ic/food_16x9_832...
# 17  https://ichef.bbci.co.uk/food/ic/food_16x9_832...

# %% [markdown]
# # Характеристики датафрейма

# %%
#размеры датафрейма

print(postcards.shape)
print(recipes.shape) # обычный питонский len тоже будет работать
# Out:
# (7, 2)
# (42, 6)

# %%
print(len(postcards))
print(len(postcards.columns))
# Out:
# 7
# 2

# %%
# описание датафрейма

print(postcards.info())
print()
print(recipes.info())

# object = питонская строка
# int64 = питонский инт
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Maria to Julia
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    7 non-null      object
#  1   age     7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         42 non-null     object
#  1   Time          42 non-null     int64
#  2   Servings      42 non-null     object
#  3   Ingredients   42 non-null     object
#  4   Instructions  42 non-null     object
#  5   Image         42 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.1+ KB
# None

# %%
# .astype() позволяет изменить тип колонки, если нужно

postcards["age"] = postcards["age"].astype("int64")
print(postcards.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Maria to Julia
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    7 non-null      object
#  1   age     7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes
# None

# %%
postcards
# Out:
#              city  age
# Maria      London   37
# Lorenzo     Milan   28
# Oleg     Canberra   31
# Hans      Calgary   80
# Mark        Milan   55
# Alex       Krakow   35
# Julia    Murmansk   43

# %% [markdown]
# ### Как посмотреть, где живет конкретный человек?
#
# Чтобы найти нужную строку, нам нужны индексы.
# Посмотрим на примере датасета с людьми и городами. У нашего датафрейма есть две оси: по строкам(нулевая, она же  index) и столбцам(первая, она же columns)

# %%
print(postcards.index) # смотрим на индексы = имена строк (если они есть)
# если имена строк не заданы, pandas просто пронумерует их от 0
# Out:
# Index(['Maria', 'Lorenzo', 'Oleg', 'Hans', 'Mark', 'Alex', 'Julia'], dtype='object')

# %%
print(postcards.columns) # смотрим на столбцы
# Out:
# Index(['city', 'age'], dtype='object')

# %%
# пересечение индексов выдаст конкретную ячейку: ищем где живет Мария

print(postcards.loc['Maria']["city"])
# Out:
# London

# %% [markdown]
# **Получить строку по индексу** можно двумя способами:
#
# - именной индекс, по "названию" строки в колонке "Index", (первая колонка датафрейма, у нас это имена людей)
# - порядковый индекс, по номеру строки в датафрейме (нумерация с 0)
#
# Для именного поиска понадобится метод ```.loc[]```, для порядкового -- ```.iloc[]```

# %%
print(postcards.iloc[3])

print(postcards.loc["Hans"]) # только если индексы в датасете есть!
# Out:
# city    Calgary
# age          80
# Name: Hans, dtype: object
# city    Calgary
# age          80
# Name: Hans, dtype: object

# %% [markdown]
# **Указав название колонки**,  можно аналогично посмотреть все значения в ней

# %%
postcards["age"] # очень похоже на получение значения по ключу словаря
# Out:
# Maria      37
# Lorenzo    28
# Oleg       31
# Hans       80
# Mark       55
# Alex       35
# Julia      43
# Name: age, dtype: int64

# %%
# посмотрите на все города
postcards['city'] # универсальный вариант

# postcards.city # краткая запись
# Только тогда, когда наш столбец назвается одним словом без пробелов латинскими буквами
# Out:
# Maria        London
# Lorenzo       Milan
# Oleg       Canberra
# Hans        Calgary
# Mark          Milan
# Alex         Krakow
# Julia      Murmansk
# Name: city, dtype: object

# %%
postcards
# Out:
#              city  age
# Maria      London   37
# Lorenzo     Milan   28
# Oleg     Canberra   31
# Hans      Calgary   80
# Mark        Milan   55
# Alex       Krakow   35
# Julia    Murmansk   43

# %% [markdown]
# # Операции с датафреймами

# %% [markdown]
# ### Добавление колонок и строк в датафрейм

# %% [markdown]
# В датафрейм можно добавить новые колонки: понадобится метод ```.assign()```

# %%
postcards = postcards.assign(job=['Artist', "Teacher", "Chef", "Artist", "Manager", "Chef", "Engineer"])
postcards

# print(postcards)
# Out:
#              city  age       job
# Maria      London   37    Artist
# Lorenzo     Milan   28   Teacher
# Oleg     Canberra   31      Chef
# Hans      Calgary   80    Artist
# Mark        Milan   55   Manager
# Alex       Krakow   35      Chef
# Julia    Murmansk   43  Engineer

# %%
# 2 способ - похож на добавление новой пары ключ-значение в питонский словарь
degrees = ['BA', 'MA', 'MA', 'PhD', 'Postdoc', 'BA', 'PhD']
postcards["degree"] = degrees

postcards
# Out:
#              city  age       job   degree
# Maria      London   37    Artist       BA
# Lorenzo     Milan   28   Teacher       MA
# Oleg     Canberra   31      Chef       MA
# Hans      Calgary   80    Artist      PhD
# Mark        Milan   55   Manager  Postdoc
# Alex       Krakow   35      Chef       BA
# Julia    Murmansk   43  Engineer      PhD

# %% [markdown]
# Добавить строки тоже можно:
#
# ранее метод назывался ```.append()```
#
# но скоро его удалят из библиотеки, так что сразу пробуем ```.concat()```

# %%
pd.DataFrame(["NY", 36, "Engineer", "MA"]).T
# Out:
#     0   1         2   3
# 0  NY  36  Engineer  MA

# %%
df = pd.DataFrame(["NY", 36, "Engineer", "MA"]).T
df.index = ["Alice"]
df.columns = postcards.columns
df
# Out:
#       city age       job degree
# Alice   NY  36  Engineer     MA

# %%
# соединяем два df
# сначала посмотрим

pd.concat([postcards, df])
# Out:
#              city age       job   degree
# Maria      London  37    Artist       BA
# Lorenzo     Milan  28   Teacher       MA
# Oleg     Canberra  31      Chef       MA
# Hans      Calgary  80    Artist      PhD
# Mark        Milan  55   Manager  Postdoc
# Alex       Krakow  35      Chef       BA
# Julia    Murmansk  43  Engineer      PhD
# Alice          NY  36  Engineer       MA

# %%
# все отлично, перезапишем перемнную postcards

postcards = pd.concat([postcards, df])
postcards
# Out:
#              city age       job   degree
# Maria      London  37    Artist       BA
# Lorenzo     Milan  28   Teacher       MA
# Oleg     Canberra  31      Chef       MA
# Hans      Calgary  80    Artist      PhD
# Mark        Milan  55   Manager  Postdoc
# Alex       Krakow  35      Chef       BA
# Julia    Murmansk  43  Engineer      PhD
# Alice          NY  36  Engineer       MA
# Alice          NY  36  Engineer       MA
# Alice          NY  36  Engineer       MA
# Alice          NY  36  Engineer       MA
# Alice          NY  36  Engineer       MA

# %% [markdown]
# а теперь запустите ячейку выше несколько раз...

# %% [markdown]
# ### что делать, если добавились ненужные строки?

# %% [markdown]
# Если есть дубликаты уже существующих строк, понадобится метод ```.drop_duplicates()```

# %%
postcards.drop_duplicates() # посмотрим, что произойдет
# изменения не вступили
# Out:
#              city age       job   degree
# Maria      London  37    Artist       BA
# Lorenzo     Milan  28   Teacher       MA
# Oleg     Canberra  31      Chef       MA
# Hans      Calgary  80    Artist      PhD
# Mark        Milan  55   Manager  Postdoc
# Alex       Krakow  35      Chef       BA
# Julia    Murmansk  43  Engineer      PhD
# Alice          NY  36  Engineer       MA

# %%
postcards.drop_duplicates(inplace=True)
# postcards.drop_duplicates() только покажет, что случится, если удалить дубликаты
# inplace=True приведет удаление в действие
postcards
# Out:
#              city age       job   degree
# Maria      London  37    Artist       BA
# Lorenzo     Milan  28   Teacher       MA
# Oleg     Canberra  31      Chef       MA
# Hans      Calgary  80    Artist      PhD
# Mark        Milan  55   Manager  Postdoc
# Alex       Krakow  35      Chef       BA
# Julia    Murmansk  43  Engineer      PhD
# Alice          NY  36  Engineer       MA
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# postcards.groupby('city').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# postcards.groupby('age').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# postcards.groupby('job').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# postcards.groupby('degree').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['age'].value_counts()
#     for x_label, grp in postcards.groupby('city')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('city')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['job'].value_counts()
#     for x_label, grp in postcards.groupby('age')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('age')
# _ = plt.ylabel('job')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['degree'].value_counts()
#     for x_label, grp in postcards.groupby('job')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('job')
# _ = plt.ylabel('degree')

# %% [markdown]
# Если удалить нужно любую строку или столбец, понадобится метод ```.drop()```
# - axis=0 если нужно удалить строку
# - axis=1 если нужно удалить колонку

# %%
postcards.drop("Mark", axis=0)
# Out:
#              city age       job degree
# Maria      London  37    Artist     BA
# Lorenzo     Milan  28   Teacher     MA
# Oleg     Canberra  31      Chef     MA
# Hans      Calgary  80    Artist    PhD
# Alex       Krakow  35      Chef     BA
# Julia    Murmansk  43  Engineer    PhD
# Alice          NY  36  Engineer     MA

# %%
postcards.drop("city", axis=1)
# Out:
#         age       job   degree
# Maria    37    Artist       BA
# Lorenzo  28   Teacher       MA
# Oleg     31      Chef       MA
# Hans     80    Artist      PhD
# Mark     55   Manager  Postdoc
# Alex     35      Chef       BA
# Julia    43  Engineer      PhD
# Alice    36  Engineer       MA

# %% [markdown]
# Аналогично, чтобы изменения вступили в силу, реультат выражения нужно сохранить в переменную, либо добавить аргумент inplace=True

# %%
postcards.drop("city", axis=1, inplace=True)
# в этой ячейке можете попробовать

# %% [markdown]
# ### Сохранение датафрейма в файл

# %%
# df = pd.read_csv('название файла', sep=',')
# открытие

# df.to_csv('название.csv', sep=',', encoding='utf-8')

# %%
# сохраним в .csv, xlsx файл

postcards.to_csv('postcards.csv')

postcards.to_excel('postcards.xlsx')

# %% [markdown]
# ### Фильтры и прочие манипуляции

# %%
import numpy as np
arr = np.array([34, 6464, -6, 0])
arr > 0
# Out:
# array([ True,  True, False, False])

# %%
postcards['age'] < 50
# Out:
# Maria       True
# Lorenzo     True
# Oleg        True
# Hans       False
# Mark       False
# Alex        True
# Julia       True
# Alice       True
# Name: age, dtype: bool

# %%
# посмотрим, кто работает шеф-поваром

print(postcards["job"] == "Chef")
# Out:
# Maria      False
# Lorenzo    False
# Oleg        True
# Hans       False
# Mark       False
# Alex        True
# Julia      False
# Alice      False
# Name: job, dtype: bool

# %%
# квадратные скобки создают подвыборку из датасета, удовлетворяющую условиям

postcards[  postcards["job"] == "Chef"  ]
# Out:
#           city age   job degree
# Oleg  Canberra  31  Chef     MA
# Alex    Krakow  35  Chef     BA

# %%
# поищем всех людей старше 40

age_40 = postcards[  postcards["age"] > 40  ]
age_40
# Out:
#            city age       job   degree
# Hans    Calgary  80    Artist      PhD
# Mark      Milan  55   Manager  Postdoc
# Julia  Murmansk  43  Engineer      PhD

# %%
# условия можно компоновать логическими операторами, но каждое отдельное условие берем в скобки ()
# синтаксис: df[ (условие1) оператор (условие2) ]

# ищем, кто старше 30 и не работает шеф-поваром

postcards[  (postcards["age"] > 30)  &  (postcards["job"] != "Chef")  ]

# & = и, | = или из питонских множеств
# обычные and, or, not не работают
# Out:
#            city age       job   degree
# Maria    London  37    Artist       BA
# Hans    Calgary  80    Artist      PhD
# Mark      Milan  55   Manager  Postdoc
# Julia  Murmansk  43  Engineer      PhD
# Alice        NY  36  Engineer       MA

# %% [markdown]
# Над значениями в колонках можно производить различные операции:
# * например, арифметические (если данные количественные):

# %%
print(postcards["age"].sum()) # работает всегда
print(postcards.age.sum()) # краткая запись, работает с простыми названиями из 1 слова латиницей без пробелов
# Out:
# 345
# 345

# %%
print(postcards.age.sum())
print(postcards.age.mean())
print(postcards.age.min())
print(postcards.age.max())
# Out:
# 345
# 43.125
# 28
# 80

# %%
postcards.describe() # аналог summary в R
# Out:
#          city  age     job degree
# count       8    8       8      8
# unique      7    8       5      4
# top     Milan   37  Artist     MA
# freq        2    1       2      3

# %% [markdown]
# Если данные категориальные, можно искать уникальные значения, упорядочивать по алфавиту и тд

# %%
print(postcards.job.values) # все значения в виде массива
print(postcards.job.unique()) # все уникальные в колонке
print(postcards.job.nunique()) # сколько уникальных в колонке
# Out:
# ['Artist' 'Teacher' 'Chef' 'Artist' 'Manager' 'Chef' 'Engineer' 'Engineer']
# ['Artist' 'Teacher' 'Chef' 'Manager' 'Engineer']
# 5

# %% [markdown]
# ### Задание 1: пингвины
#
# Вы работаете с датасетом о пингвинах трех видов, обитающих на трех разных островах. Найдите:
# - среднюю массу тела пингвинов (body_mass_g)
# - количество пингвинов вида Adelie
# - пингвина вида Gentoo с самым длинным плавником (flipper_length_mm)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/penguins.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
# ваш код здесь

# %% [markdown]
# Ответы ниже:

# %%
# @title
print(df['body_mass_g'].mean())

# %%
# @title
print(df[  df['species'] == 'Adelie' ].shape) # 152 - количество пингвинов вида Adelie

# %%
# @title

max_flipper = df[   df['species'] == 'Gentoo'  ]['flipper_length_mm'].max()
#               # фильтр                        # выбор столбца      # максимум

print(max_flipper) # максимальная длина плавника у пингвина вида Gentoo

df[  (df['species'] == 'Gentoo') & (df['flipper_length_mm'] == max_flipper) ] # два фильтра, посмотрим на этого пингвина

# %% [markdown]
# ### Задание 2: колонии
#
# Вы работаете с датасетом от Гарвардского университета, в котором хранится информация о государствах - бывших колониях. Посчитайте:
# * количество этих государств (Country Name)
# * среднюю продолжительность колониального периода (COLYEARS)
# * максимальную продолжительность зависимости (COLYEARS)
# * количество государств, в которых деколонизация была длительной ('decolonization' - 'long')
#
# Скачать данные можно здесь: https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/Colonial.csv

# %%
# ваш код здесь
df = pd.read_csv('https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/Colonial.csv', sep=';')
df
# Out:
#    Country Code      Country Name metropolis   onset     end  COLYEARS  \
# 0           AFG       Afghanistan          x  1880.0  1919.0        39
# 1           AGO            Angola          P  1506.0  1975.0       469
# 2           ARE  Unit. Arab. Emir         UK  1850.0  1971.0       121
# 3           BDI           Burundi          B  1897.0  1962.0        65
# 4           BEN             Benin          F  1878.0  1960.0        82
# ..          ...               ...        ...     ...     ...       ...
# 81          VUT           Vanuatu       UK/F  1887.0  1980.0        93
# 82          ZAF      South Africa         UK  1652.0  1994.0       342
# 83          ZAR   Zaire/Congo Dem          B  1879.0  1960.0        81
# 84          ZMB            Zambia         UK  1889.0  1964.0        75
# 85          ZWE          Zimbabwe         UK  1888.0  1980.0        92
#
#     violence  administration decolonization foreign trade plantations  \
# 0        4.0             0.0           long     not appl.          no
# 1        6.0             1.0          short  preferential   extensive
# 2        2.0             1.0           long     open door          no
# 3        4.0             0.0          short     open door      little
# 4        2.0             1.0           long  preferential      little
# ..       ...             ...            ...           ...         ...
# 81       2.0             1.0           long     open door   extensive
# 82       4.0             1.0           long  preferential   extensive
# 83       4.0             1.0          short     open door   extensive
# 84       2.0             1.0           long     open door          no
# 85       5.0             1.0           long  preferential   extensive
#
#    gold/silver  missionary  level
# 0           no         0.0   28.0
# 1    extensive         3.0   88.0
# 2           no         0.0   22.0
# 3       little         3.0   65.0
# 4           no         3.0   56.0
# ..         ...         ...    ...
# 81          no         4.0   55.0
# 82   extensive         4.0  100.0
# 83   extensive         3.0   73.0
# 84      little         4.0   59.0
# 85   extensive         3.0   91.0
#
# [86 rows x 14 columns]

# %%
# @title
df.shape # количество государств - 86

# %%
# @title
df['COLYEARS'].mean()

# %%
# @title
df['COLYEARS'].max()

# %%
# @title
df[  df['decolonization'] == 'long'  ].shape # 51 государство

# %% [markdown]
# ### Задание 3: тревожность и телевидение
#
# Вы изучаете взаимосвязь тревожности и просмотра телевиденья. Вам необходимо расчитать следующие характеристики:
#
# * Сколько человек приняло участие в исследовании?
# * Каков минимальный и максимальный возраст участников?
# * Сколько в выборке женщин?
# * Какое среднее значение тревожности наблюдается в данных?
#
# Скачать данные можно здесь: https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/socio.csv

# %%
# ваш код здесь
df = pd.read_csv('https://raw.githubusercontent.com/AnnSenina/Python_CL_2023/main/data/socio.csv')
df
# Out:
#      ID  Gender  Age        Date  Anxiety  TV_hours
# 0     1  Female   35  2015-03-14        3         1
# 1     2  Female   35  2015-03-02        3         1
# 2     3  Female   26  2015-08-04        6         1
# 3     4  Female   32  2015-06-29        4         4
# 4     5  Female   45  2015-08-01        7         4
# ..  ...     ...  ...         ...      ...       ...
# 95   96  Female   43  2015-04-19        9         1
# 96   97  Female   37  2015-06-19        3         6
# 97   98    Male   30  2015-01-15        5         5
# 98   99    Male   37  2015-05-26        6         3
# 99  100  Female   35  2015-02-14        9         5
#
# [100 rows x 6 columns]

# %%
# @title
df.shape # 100 человек

# %%
# @title
print(df['Age'].max())
print(df['Age'].min())

# %%
# @title
df[  df['Gender'] == 'Female'  ].shape # 55 женщин

# %%
# @title
df['Anxiety'].mean()
